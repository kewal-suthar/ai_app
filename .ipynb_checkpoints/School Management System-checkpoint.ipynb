# %%
#School Management System


#def admin():
 #   nos=int(input("Enter a number of students: "))


rafay=["hello",123,1.2,{1:2}]

#type(rafay[2]) #to display data stype (like string, int , float  etc)

rafay.append("Kewal")

# %%
rafay
# Out:
# ['hello', 123, 1.2, {1: 2}, 'Kewal']

# %%
rafay.append(123)

# %%
rafay
# Out:
# ['hello', 123, 1.2, {1: 2}, 'Kewal', 'kewal', 'Kewal', 123]

# %%
rafay.count(1.2)
# Out:
# 1

# %%
rafay.append(1.333)

# %%
rafay.append(1.2)

# %%
rafay
# Out:
# ['hello', 123, 1.2, {1: 2}, 'Kewal', 'kewal', 'Kewal', 123, 1.333, 1.2]

# %%
#School Management System

def admin():
    nos=int(input("Enter a number of students you want to add: "))
